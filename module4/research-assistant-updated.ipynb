# %%
# --- MULTI-AGENT RESEARCH ASSISTANT: SALES INTELLIGENCE EDITION ---


# %pip install -U langchain_openai langgraph
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")
_set_env("LANGSMITH_API_KEY")

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langchain-academy"

# --- Overview ---
# This combines Map-Reduce and Parallelization into one research assistant.
# It performs:
# 1️⃣ Map-Reduce → Identify the best-performing product in a category.
# 2️⃣ Parallelization → Generate quick summaries for each product.

from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send
from typing_extensions import TypedDict
from typing import Annotated
import operator
from pydantic import BaseModel
from IPython.display import Image

# --- Model ---
model = ChatOpenAI(model="gpt-4o", temperature=0)

# --- Prompts ---
products_prompt = """Generate a list of 4 products from this category: {category}."""
sales_summary_prompt = """Write a concise summary (2-3 lines) describing the sales trends, key markets, and growth opportunities for {product}."""
best_product_prompt = """Here are sales summaries of several products in the category {category}.

Choose the best-performing product overall and return its ID (starting from 0 for the first). Summaries:

{summaries}"""

# --- Models ---
class Products(BaseModel):
    products: list[str]

class ProductSummary(BaseModel):
    summary: str

class BestProduct(BaseModel):
    id: int

# --- State ---
class OverallState(TypedDict):
    category: str
    products: list
    summaries: Annotated[list, operator.add]
    best_product: str

# --- Node 1: Generate product list ---
def generate_products(state: OverallState):
    prompt = products_prompt.format(category=state["category"])
    response = model.with_structured_output(Products).invoke(prompt)
    return {"products": response.products}

# --- Node 2: Parallel summaries ---
class ProductState(TypedDict):
    product: str

def generate_summary(state: ProductState):
    prompt = sales_summary_prompt.format(product=state["product"])
    response = model.with_structured_output(ProductSummary).invoke(prompt)
    return {"summaries": [f"{state['product']}: {response.summary}"]}

def continue_to_summaries(state: OverallState):
    return [Send("generate_summary", {"product": p}) for p in state["products"]]

# --- Node 3: Reduce phase (find best product) ---
def best_product(state: OverallState):
    summaries = "\n\n".join(state["summaries"])
    prompt = best_product_prompt.format(category=state["category"], summaries=summaries)
    response = model.with_structured_output(BestProduct).invoke(prompt)
    return {"best_product": state["summaries"][response.id]}

# --- Node 4: Final reporting ---
def final_report(state: OverallState):
    print("\n=== FINAL SALES RESEARCH REPORT ===\n")
    for s in state["summaries"]:
        print(s)
    print(f"\n🏆 Best Performing Product:\n{state['best_product']}")
    print("\n✅ Research assistant analysis complete.")
    return {}

# --- GRAPH ---
graph = StateGraph(OverallState)
graph.add_node("generate_products", generate_products)
graph.add_node("generate_summary", generate_summary)
graph.add_node("best_product", best_product)
graph.add_node("final_report", final_report)

graph.add_edge(START, "generate_products")
graph.add_conditional_edges("generate_products", continue_to_summaries, ["generate_summary"])
graph.add_edge("generate_summary", "best_product")
graph.add_edge("best_product", "final_report")
graph.add_edge("final_report", END)

# --- Compile & Visualize ---
app = graph.compile()
Image(app.get_graph().draw_mermaid_png())

# --- RUN ---
for s in app.stream({"category": "Electronics"}):
    print(s)
# Out:
# Requirement already satisfied: langchain_openai in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (1.0.1)
# Requirement already satisfied: langgraph in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langchain_openai) (1.0.2)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langchain_openai) (2.5.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langgraph) (3.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langgraph) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: pydantic>=2.7.4 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langgraph) (2.12.3)
# Requirement already satisfied: xxhash>=3.5.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_openai) (0.4.37)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_openai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_openai) (4.15.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.11.0)
# Requirement already satisfied: httpx>=0.25.2 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.11.1)
# Requirement already satisfied: sniffio in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2025.9.18)
# Requirement already satisfied: requests>=2.26.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain_openai) (3.11)
# Requirement already satisfied: certifi in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_openai) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_openai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.5.0)
# Requirement already satisfied: colorama in d:\lakshya\.venv\scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain_openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# {'generate_products': {'products': ['1. **Sony WH-1000XM4 Wireless Noise-Canceling Headphones**  \n   - Features: Industry-leading noise cancellation, up to 30 hours of battery life, touch sensor controls, and voice assistant compatibility.\n   - Price: $349.99\n   - Description: Experience the ultimate in wireless freedom with these premium headphones that deliver exceptional sound quality and comfort.\n\n2. **Apple iPad Air (5th Generation)**  \n   - Features: 10.9-inch Liquid Retina display, A14 Bionic chip, 64GB storage, and support for Apple Pencil (2nd generation).\n   - Price: $599.00\n   - Description: A powerful and versatile tablet that combines performance with portability, perfect for work, play, and creativity.\n\n3. **Samsung Galaxy S21 Ultra 5G Smartphone**  \n   - Features: 6.8-inch Dynamic AMOLED 2X display, 108MP camera, 5,000mAh battery, and 5G connectivity.\n   - Price: $1,199.99\n   - Description: A flagship smartphone that offers cutting-edge technology, stunning photography capabilities, and seamless connectivity.\n\n4. **LG OLED55CXPUA Alexa Built-In CX 55" 4K Smart OLED TV**  \n   - Features: 4K Ultra HD resolution, AI-powered picture quality, Dolby Vision IQ, and built-in Alexa.\n   - Price: $1,499.99\n   - Description: Immerse yourself in a cinematic viewing experience with this smart TV that delivers vibrant colors and deep blacks.']}}
# {'generate_summary': {'summaries': ['1. **Sony WH-1000XM4 Wireless Noise-Canceling Headphones**  \n   - Features: Industry-leading noise cancellation, up to 30 hours of battery life, touch sensor controls, and voice assistant compatibility.\n   - Price: $349.99\n   - Description: Experience the ultimate in wireless freedom with these premium headphones that deliver exceptional sound quality and comfort.\n\n2. **Apple iPad Air (5th Generation)**  \n   - Features: 10.9-inch Liquid Retina display, A14 Bionic chip, 64GB storage, and support for Apple Pencil (2nd generation).\n   - Price: $599.00\n   - Description: A powerful and versatile tablet that combines performance with portability, perfect for work, play, and creativity.\n\n3. **Samsung Galaxy S21 Ultra 5G Smartphone**  \n   - Features: 6.8-inch Dynamic AMOLED 2X display, 108MP camera, 5,000mAh battery, and 5G connectivity.\n   - Price: $1,199.99\n   - Description: A flagship smartphone that offers cutting-edge technology, stunning photography capabilities, and seamless connectivity.\n\n4. **LG OLED55CXPUA Alexa Built-In CX 55" 4K Smart OLED TV**  \n   - Features: 4K Ultra HD resolution, AI-powered picture quality, Dolby Vision IQ, and built-in Alexa.\n   - Price: $1,499.99\n   - Description: Immerse yourself in a cinematic viewing experience with this smart TV that delivers vibrant colors and deep blacks.: 1. **Sony WH-1000XM4 Wireless Noise-Canceling Headphones**: Sales are strong in tech-savvy markets like the US and Europe, driven by demand for high-quality audio and remote work setups. Growth opportunities lie in expanding into emerging markets and enhancing features with AI integration.\n\n2. **Apple iPad Air (5th Generation)**: The iPad Air sees robust sales in education and creative sectors, with key markets in North America and Asia. Growth potential exists in expanding educational partnerships and enhancing AR capabilities.\n\n3. **Samsung Galaxy S21 Ultra 5G Smartphone**: This smartphone is popular in tech-forward regions such as South Korea and the US, with sales driven by its advanced camera and 5G capabilities. Growth opportunities include expanding 5G infrastructure and targeting professional photographers.\n\n4. **LG OLED55CXPUA 4K Smart OLED TV**: Sales are strong in North America and Europe, fueled by demand for premium home entertainment systems. Growth opportunities include tapping into the gaming community and enhancing smart home integration features.']}}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 113
#     110 Image(app.get_graph().draw_mermaid_png())
#     112 # --- RUN ---
# --> 113 for s in app.stream({"category": "Electronics"}):
#     114     print(s)
#
# File d:\lakshya\.venv\Scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\Lib\site-packages\langgraph\pregel\main.py:2679, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2677 for task in loop.match_cached_writes():
#    2678     loop.output_writes(task.id, task.writes, cached=True)
# -> 2679 for _ in runner.tick(
#    2680     [t for t in loop.tasks.values() if not t.writes],
#    2681     timeout=self.step_timeout,
#    2682     get_waiter=get_waiter,
#    2683     schedule_task=loop.accept_push,
#    2684 ):
#    2685     # emit output
#    2686     yield from _output(
#    2687         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2688     )
#    2689 loop.after_tick()
#
# File d:\lakshya\.venv\Scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File d:\lakshya\.venv\Scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\lakshya\.venv\Scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File d:\lakshya\.venv\Scripts\intro-to-langsmith\notebooks\langchain-academy\lc-academy-env\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# Cell In[1], line 84, in best_product(state)
#      82 prompt = best_product_prompt.format(category=state["category"], summaries=summaries)
#      83 response = model.with_structured_output(BestProduct).invoke(prompt)
# ---> 84 return {"best_product": state["summaries"][response.id]}
#
# IndexError: list index out of range
# During task with name 'best_product' and id '7d79c2e6-f165-76a4-5554-9ef3a1f958c5'
